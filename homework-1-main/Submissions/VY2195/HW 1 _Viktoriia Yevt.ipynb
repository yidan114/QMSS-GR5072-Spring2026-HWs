# %% [markdown]
# Homework 1

# %% [markdown]
# Viktoriia Yevtushenko

# %% [markdown]
# *vy2195*

# %% [markdown]
# ## Table of Contents
# 1. [Project Overview](#bullet1)
# 2. [How the Project Works](#bullet2)
#    - [Why It’s Interesting](#bullet3)
# 3. [Visualization](#bullet4)
# 4. [Conclusion](#bullet5)

# %% [markdown]
# ## Project Overview <a class="anchor" id="bullet1"></a>
#
# The project I chose is **wttr.in**, an open-source weather service hosted on GitHub.
# It allows users to check the weather directly from the command line using a simple text-based interface.
#
# 🔗 GitHub Repository: https://github.com/chubin/wttr.in

# %% [markdown]
# ## How the Project Works <a class="anchor" id="bullet2"></a>
#
# The wttr.in project uses public weather data and displays it in a clean, readable format that works in terminals, browsers, and even curl commands.
#
# ### Why It’s Interesting <a class="anchor" id="bullet3"></a>
#
# - It works without a graphical interface
# - It is **free and open-source**
# - It supports multiple cities and locations
# - It can be accessed using simple commands like *curl wttr.in*

# %% [markdown]
# ## Visualization <a class="anchor" id="bullet4"></a>
#
# Below is an example of the weather output generated by wttr.in:

# %% [markdown]
# ![image.png](attachment:1f93612f-3c97-47df-b1d0-2980a9e03214.png)![image.png](attachment:30fcbee5-3b8f-4921-9c96-f42d470f72ec.png)

# %% [markdown]
# ## Conclusion <a class="anchor" id="bullet5"></a>
#
# In conclusion, wttr.in is a simple yet powerful project that demonstrates how useful tools do not always require complex user interfaces.
# Its clean design and accessibility make it a great example of practical open-source software.

# %% [markdown]
# ## Reflection on Git and GitHub
#
# When I looked at the commit history for my Python script, the code looked familiar because it was written in a standard `.py` format.
# However, the commit history for the Jupyter Notebook looked foreign because notebooks are stored as JSON files behind the scenes, which makes the changes harder to read compared to plain Python scripts.
