# %% [markdown]
# # ***HW1-report seaborn***

# %% [markdown]
# ### *project link*

# %% [markdown]
# https://github.com/mwaskom/seaborn

# %% [markdown]
# ## Table of Contents
# - [What is Seaborn](#bullet1)
# - [Example plot](#bullet2)
# - [Key takeaways](#bullet3)

# %% [markdown]
# <a class="anchor" id="bullet1"></a>
# ## What is Seaborn

# %% [markdown]
# - Seaborn is a Python *visualization library*.
# - It works well with pandas DataFrames.
# - It builds on **matplotlib**.

# %% [markdown]
# <a class="anchor" id="bullet2"></a>
# ## Example plot

# %% [markdown]
# ![logo-mark-darkbg.png](attachment:0f264061-a547-4e4f-848f-eb9c99848c15.png)

# %% [markdown]
# <a class="anchor" id="bullet3"></a>
# ## Key takeaways

# %% [markdown]
# When I checked my commit history in GitHub / GitHub Desktop, the Jupyter Notebook file did not look very familiar to me. To be honest, I don’t have a coding background, so both the notebook and the python script mostly just look like “code text” to me at first glance.
# But I did notice something: for the Jupyter Notebook, the changes looked more confusing and “foreign,” because it didn’t display like normal code. It seemed to include extra information beyond what I typed.
