# %% [markdown]
# ### Import Packages

# %%
 # you only need to install once !
# !pip install spotipy
# pip install yfinance

# %%
import requests
import pandas as pd
# !pip install spotipy  # you only need to install once !
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Part 1: Leverage the lecture code to answer these questions
#
# 1. Use the BLS Data Finder 1.1 available [here](https://beta.bls.gov/dataQuery/find?st=0&r=20&more=0) to import a BLS variable/field (using the BLS web API) of your choosing.

# %%
# BLS API v1 url
base_url = 'https://api.bls.gov/publicAPI/v1/timeseries/data/'

# %%
# BLS series id for the Average hourly earnings of all employees (total private)
series = {'id': 'APU000074714',
          'name': 'Average Hourly Earnings of all Private Employees'}

# %%
# Combine the base url and series id into a single string which is the API url with data. 
# Print a link to the data.
data_url = '{}{}'.format(base_url, series['id'])
print(data_url)
# Out:
# https://api.bls.gov/publicAPI/v1/timeseries/data/APU000074714

# %%
r = requests.get(data_url).json()
print('Status: ' + r['status'])
# Out:
# Status: REQUEST_NOT_PROCESSED

# %%
print(r.keys()) # The results key has the data we want
# Out:
# dict_keys(['status', 'responseTime', 'message', 'Results'])

# %%
r = r['Results']['series'][0]['data']
print(r[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 r = r['Results']['series'][0]['data']
#       2 print(r[0])
#
# KeyError: 'series'

# %%
# Reformat to a pandas object
dates = ['{} {}'.format(i['period'][1:], i['year']) for i in r]
index = pd.to_datetime(dates)
data = {series['id']: [float(i['value']) for i in r],
        'footnotes': [i['footnotes'][0] for i in r]}

df = pd.DataFrame(index=index, data=data).iloc[::-1]

df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Reformat to a pandas object
# ----> 2 dates = ['{} {}'.format(i['period'][1:], i['year']) for i in r]
#       3 index = pd.to_datetime(dates)
#       4 data = {series['id']: [float(i['value']) for i in r],
#       5         'footnotes': [i['footnotes'][0] for i in r]}
#
# TypeError: string indices must be integers, not 'str'

# %%
# Calculate the average value for the period and plot both the monthly values and average value to look for trends
df['mean'] = df[series['id']].mean()
df[[series['id'], 'mean']].plot(title=series['name'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Calculate the average value for the period and plot both the monthly values and average value to look for trends
# ----> 2 df['mean'] = df[series['id']].mean()
#       3 df[[series['id'], 'mean']].plot(title=series['name'])
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# 2. Using the BLS web API, create your own custom function which can interact with the BLS web API. Your function should take three input parameters: name base_url_in, series_in, and title_in and return the relevant data series as a pd.DataFrame object. Test your function by replicating the GET request you sent above for #1.

# %%
# Create a function to import the data
def create_api_df(base_url_in, series_in, title_in):
    tmp_series = {'id': series_in,
                  'name': title_in}
    tmp_data_url = '{}{}'.format(base_url_in, tmp_series['id'])
    #tmp_r = requests.get(tmp_data_url).json()
    #tmp_r = tmp_r['Results']['series'][0]['data']
    
    # Reformat to a pandas object
    dates = ['{} {}'.format(i['periodName'], i['year']) for i in r]
    index = pd.to_datetime(dates)
    data = {series['id']: [float(i['value']) for i in r]}

    tmp_df = pd.DataFrame(index=index, data=data).iloc[::-1]
    print(title_in)
    return tmp_df

# %%
# Create a function to import the data
def create_api_df(base_url_in, series_in, title_in):
    tmp_series = {'id': series_in,
                  'name': title_in}
    tmp_data_url = '{}{}'.format(base_url_in, tmp_series['id'])
    tmp_r = requests.get(tmp_data_url).json()
    tmp_r = tmp_r['Results']['series'][0]['data']
    
    # Reformat to a pandas object
    dates = ['{} {}'.format(i['periodName'], i['year']) for i in tmp_r]
    index = pd.to_datetime(dates)
    data = {series['id']: [float(i['value']) for i in tmp_r]}

    tmp_df = pd.DataFrame(index=index, data=data).iloc[::-1]
    print(title_in)
    return tmp_df

dat = create_api_df(base_url, 'CES0500000003', 'Average Hourly Earnings of all Private Employees')
dat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 18
#      15     print(title_in)
#      16     return tmp_df
# ---> 18 dat = create_api_df(base_url, 'CES0500000003', 'Average Hourly Earnings of all Private Employees')
#      19 dat
#
# Cell In[48], line 7, in create_api_df(base_url_in, series_in, title_in)
#       5 tmp_data_url = '{}{}'.format(base_url_in, tmp_series['id'])
#       6 tmp_r = requests.get(tmp_data_url).json()
# ----> 7 tmp_r = tmp_r['Results']['series'][0]['data']
#       9 # Reformat to a pandas object
#      10 dates = ['{} {}'.format(i['periodName'], i['year']) for i in tmp_r]
#
# KeyError: 'series'

# %% [markdown]
# 3. Go to these three links: [link1](https://beta.bls.gov/dataViewer/view/timeseries/APU0000709112), [link2](https://beta.bls.gov/dataViewer/view/timeseries/APU000074714), [link3](https://beta.bls.gov/dataViewer/view/timeseries/APU0000708111). On these webpages, you will see three different time series data sets. For each, you will also see both a Series Title and ID. Using the function you wrote to fetch data from the BLS web API, import these data sets into Python as three separate `pd.Data.Frame` objects.

# %%
# Link 1
milk_df = create_api_df(base_url,'APU0000709112','Milk, fresh, whole, fortified, per gal.')
milk_df.head()
# Out:
# Milk, fresh, whole, fortified, per gal.
# C:\Users\nicho\AppData\Local\Temp\ipykernel_16868\4201150701.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   index = pd.to_datetime(dates)
#             CES0500000003
# 2023-01-01          4.204
# 2023-02-01          4.163
# 2023-03-01          4.098
# 2023-04-01          4.042
# 2023-05-01          4.042

# %%
# Link 2
gas_df = create_api_df(base_url,'APU000074714','Gasoline, unleaded regular, per gallon')
gas_df.head()
# Out:
# Gasoline, unleaded regular, per gallon
# C:\Users\nicho\AppData\Local\Temp\ipykernel_16868\4201150701.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   index = pd.to_datetime(dates)
#             CES0500000003
# 2023-01-01          3.452
# 2023-02-01          3.514
# 2023-03-01          3.551
# 2023-04-01          3.735
# 2023-05-01          3.685

# %%
# Link 3
egg_df = create_api_df(base_url,'APU0000708111','Eggs, grade A, large, per doz.')
egg_df.head()
# Out:
# Eggs, grade A, large, per doz.
# C:\Users\nicho\AppData\Local\Temp\ipykernel_16868\4201150701.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   index = pd.to_datetime(dates)
#             CES0500000003
# 2023-01-01          4.823
# 2023-02-01          4.211
# 2023-03-01          3.446
# 2023-04-01          3.270
# 2023-05-01          2.666

# %% [markdown]
# 4. Merge the data sets together into a single ```pd.DataFrame``` and make a time series plot showing how the CPI for these three goods has changed over the last 24 months. Each good should be shown as a unique line with different coloring/patterns and a matching legend (I suggest using the ```matplotlib``` library to do this).

# %%
# Merge the datasets
df_1 = pd.merge(milk_df, gas_df, left_index=True, right_index=True)
cpi_df = pd.merge(df_1, egg_df, left_index=True, right_index=True)
cpi_df = cpi_df.rename(columns={'APU0000709112': 'Milk, fresh, whole, fortified, per gal.',
                                'APU000074714': 'Gasoline, unleaded regular, per gallon', 
                                'APU0000708111': 'Eggs, grade A, large, per doz.'})
cpi_df.head()
# Out:
#             CES0500000003_x  CES0500000003_y  CES0500000003
# 2023-01-01            4.204            3.452          4.823
# 2023-02-01            4.163            3.514          4.211
# 2023-03-01            4.098            3.551          3.446
# 2023-04-01            4.042            3.735          3.270
# 2023-05-01            4.042            3.685          2.666

# %%
# Plot
plt.figure(figsize=(8, 5))
plt.plot(cpi_df.index, cpi_df.iloc[:,0], color='blue', label='Milk, fresh, whole, fortified, per gal.')
plt.plot(cpi_df.index, cpi_df.iloc[:,1], color='green', ls = 'dotted',
         label='Gasoline, unleaded regular, per gallon')
plt.plot(cpi_df.index, cpi_df.iloc[:,2], color='red', marker='s', label='Eggs, grade A, large, per doz.')
plt.title('CPI Average Price Data, U.S. city average (AP)')
plt.xlabel('Date')
plt.ylabel('Index Value')
plt.legend()
plt.show()

# %% [markdown]
# 5. In the lecture notes, refer to the section entitled "No Python Package? Manipulate URL directly". Can you update the code in the New York Times article search API URL so that you return article data for Hillary Clinton for the time range April 1, 2024 - April 4, 2024? How many TOTAL articles were returned by this API search?

# %%
# Conduct an  article search for Hillary Clinton from
# begin_date = "20220801" to end_date = '20221231'

# Create different parts of the final URL, then combine them together
article_key = "Dh5ALRSh2qe7I7FhAAj8VHxwcVO9FFy8"
term = 'Hillary+Clinton' # Need to use + to string together separate words for multiple terms
#begin_date = "20220328" # 03/28/22 had 0 hits on NYT for Hillary Clinton
begin_date = "20240401" 
end_date = "20240404"

# %%
finalurl = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=" + term + "&begin_date=" + begin_date + "&end_date=" + end_date + "&api-key=" + article_key

# %%
finalurl
# Out:
# 'http://api.nytimes.com/svc/search/v2/articlesearch.json?q=Hillary+Clinton&begin_date=20240401&end_date=20240404&api-key=Dh5ALRSh2qe7I7FhAAj8VHxwcVO9FFy8'

# %%
r_1 = requests.get(finalurl)
r_1 = r_1.json()
print(r_1.keys())
# Out:
# dict_keys(['status', 'copyright', 'response'])

# %%
data_1 = pd.DataFrame(r_1['response']['docs'])
print(data_1.shape)   # look at dim of data
print(data_1.columns) # look at columns
data_1[data_1['document_type']=='article']
# Out:
# (5, 19)
# Index(['abstract', 'byline', 'document_type', 'headline', '_id', 'keywords',
#        'multimedia', 'news_desk', 'print_page', 'print_section', 'pub_date',
#        'section_name', 'snippet', 'source', 'subsection_name',
#        'type_of_material', 'uri', 'web_url', 'word_count'],
#       dtype='object')
#                                             abstract  \
# 0  Inside the notorious “catch and kill” campaign...
# 1  Oren Etzioni was once an optimist about artifi...
# 2  Simon Rosenberg has spent the past two years t...
# 3  He oversaw design of new ballparks for the Bal...
# 4  Long before the killings of seven workers in G...
#
#                                          byline document_type  \
# 0         {'original': 'By Lachlan Cartwright'}       article
# 1  {'original': 'By Cade Metz and Tiffany Hsu'}       article
# 2             {'original': 'By Adam Nagourney'}       article
# 3           {'original': 'By Richard Sandomir'}       article
# 4               {'original': 'By Kim Severson'}       article
#
#                                             headline  \
# 0  {'main': 'What I Saw Working at The National E...
# 1  {'main': 'An A.I. Researcher Takes On Election...
# 2  {'main': 'Many Democrats Are Worried Trump Wil...
# 3  {'main': 'Larry Lucchino, Top Executive at Thr...
# 4  {'main': 'How José Andrés and His Corps of Coo...
#
#                                                  _id  \
# 0  nyt://article/3211e3f0-4388-5f19-884b-051e5821...
# 1  nyt://article/e75ea126-164f-5942-a86a-4781dfdd...
# 2  nyt://article/58c63816-3116-5608-b18d-878e39eb...
# 3  nyt://article/47823689-65b3-5250-ba60-8c10cff9...
# 4  nyt://article/5b4d71e7-2855-534f-b725-7cfd9c88...
#
#                                             keywords  \
# 0  [{'name': 'Organization', 'value': 'National E...
# 1  [{'name': 'Subject', 'value': 'Artificial Inte...
# 2  [{'name': 'Person', 'value': 'Biden, Joseph R ...
# 3  [{'name': 'Subject', 'value': 'Deaths (Obituar...
# 4  [{'name': 'Person', 'value': 'Andres, Jose (19...
#
#                                           multimedia news_desk print_page  \
# 0  {'caption': '', 'credit': 'Photo illustration ...  Magazine         26
# 1  {'caption': 'Oren Etzioni at The AI Institute....  Business          1
# 2  {'caption': 'Simon Rosenberg, a Democratic str...  Politics         18
# 3  {'caption': 'Larry Lucchino in 2008 as preside...     Obits         11
# 4  {'caption': 'José Andrés, the Spanish chef who...    Dining          9
#
#   print_section              pub_date section_name  \
# 0            MM  2024-04-03T09:04:03Z     Magazine
# 1             B  2024-04-02T16:00:12Z   Technology
# 2             A  2024-04-03T18:26:38Z         U.S.
# 3             B  2024-04-02T16:23:20Z       Sports
# 4             A  2024-04-02T22:31:38Z         Food
#
#                                              snippet              source  \
# 0  Inside the notorious “catch and kill” campaign...  The New York Times
# 1  Oren Etzioni was once an optimist about artifi...  The New York Times
# 2  Simon Rosenberg has spent the past two years t...  The New York Times
# 3  He oversaw design of new ballparks for the Bal...  The New York Times
# 4  Long before the killings of seven workers in G...  The New York Times
#
#   subsection_name type_of_material  \
# 0                             News
# 1                             News
# 2        Politics             News
# 3        Baseball  Obituary (Obit)
# 4                             News
#
#                                                  uri  \
# 0  nyt://article/3211e3f0-4388-5f19-884b-051e5821...
# 1  nyt://article/e75ea126-164f-5942-a86a-4781dfdd...
# 2  nyt://article/58c63816-3116-5608-b18d-878e39eb...
# 3  nyt://article/47823689-65b3-5250-ba60-8c10cff9...
# 4  nyt://article/5b4d71e7-2855-534f-b725-7cfd9c88...
#
#                                              web_url  word_count
# 0  https://www.nytimes.com/2024/04/03/magazine/na...        6394
# 1  https://www.nytimes.com/2024/04/02/technology/...        1089
# 2  https://www.nytimes.com/2024/04/03/us/politics...        1754
# 3  https://www.nytimes.com/2024/04/02/sports/base...        1285
# 4  https://www.nytimes.com/2024/04/02/dining/jose...        1456

# %% [markdown]
# The API search for Hillary Clinton in the date range April 1, 2024 - April 4, 2024 results were shown above. As we can see, there are 5 articles which referenced Hillary Clinton in this time frame.

# %% [markdown]
# ### Part 2: Connect to other APIs
#
# 6. In this question, we will connect to the Spotify API. Spotify has a package called ```spotipy``` which makes this easy. Using [this](https://towardsdatascience.com/extracting-song-data-from-the-spotify-api-using-python-b1e79388d50) online tutorial, import a list of the top 50 global tracks (as listed on Spotify's Global top songs playlist). **Do not embed your client_id and client_secret information in the code that you submit.** As the tutorial suggests, save those in a separate python file and import them as the variables cid and client_secret so that they are masked from us when you submit your assignment.
#
# *Hint: There's two things you need know: (1) You'll have to modify the code from this online tutorial slightly to answer the question and (2) you'll need an authenticated Spotify account. You can use your own Spotify account details if you have your own account. Or, I made a free account which you can use to answer this problem. The details for which are below.*
#
# ```cid='1d79c7320efe48be8555674d48a7fd2d'``` ```secret='34a7cabc5f624302b9bb25c29d1c8057'```

# %%
# Packages loaded at top of notebook

# %%
# Load credentials (from free account above)
cid = '1d79c7320efe48be8555674d48a7fd2d'
client_secret= '34a7cabc5f624302b9bb25c29d1c8057'

# %%
# Authenticate credentials
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
album_id = "https://open.spotify.com/album/6a8nlV9V8kPUbTTCJNVSsh"
queen_album = sp.album(album_id, market=None)
type(queen_album)
# Out:
# dict

# %%
# The next several cells export the nature of this data object, building up to the for loop which fully extracts the data elements we asked about
queen_album.keys()
# Out:
# dict_keys(['album_type', 'total_tracks', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'type', 'uri', 'artists', 'tracks', 'copyrights', 'external_ids', 'genres', 'label', 'popularity'])

# %%
queen_album['available_markets']
# Out:
# ['CA', 'US']

# %%
queen_album['total_tracks']
# Out:
# 17

# %%
queen_album['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/albums/6a8nlV9V8kPUbTTCJNVSsh/tracks?offset=0&limit=50',
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 17,
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 355466,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ljkRMigoNtu0x1mlTEsKc'},
#    'href': 'https://api.spotify.com/v1/tracks/6ljkRMigoNtu0x1mlTEsKc',
#    'id': '6ljkRMigoNtu0x1mlTEsKc',
#    'name': 'Bohemian Rhapsody - Remastered 2011',
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6ljkRMigoNtu0x1mlTEsKc',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 215333,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6hfNDGNTJBR029RmV63IoO'},
#    'href': 'https://api.spotify.com/v1/tracks/6hfNDGNTJBR029RmV63IoO',
#    'id': '6hfNDGNTJBR029RmV63IoO',
#    'name': 'Another One Bites The Dust - Remastered 2011',
#    'preview_url': None,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:6hfNDGNTJBR029RmV63IoO',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 179600,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Oj0XnWrDEl3KrwZuMQqVj'},
#    'href': 'https://api.spotify.com/v1/tracks/6Oj0XnWrDEl3KrwZuMQqVj',
#    'id': '6Oj0XnWrDEl3KrwZuMQqVj',
#    'name': 'Killer Queen - Remastered 2011',
#    'preview_url': None,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6Oj0XnWrDEl3KrwZuMQqVj',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 202440,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/52ZQTzXbbWjS4kjOcV3z5b'},
#    'href': 'https://api.spotify.com/v1/tracks/52ZQTzXbbWjS4kjOcV3z5b',
#    'id': '52ZQTzXbbWjS4kjOcV3z5b',
#    'name': 'Fat Bottomed Girls - Single Version / Remastered 2011',
#    'preview_url': None,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:52ZQTzXbbWjS4kjOcV3z5b',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 180813,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6I55r9WyH1wV1whBRacLFa'},
#    'href': 'https://api.spotify.com/v1/tracks/6I55r9WyH1wV1whBRacLFa',
#    'id': '6I55r9WyH1wV1whBRacLFa',
#    'name': 'Bicycle Race - Remastered 2011',
#    'preview_url': None,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6I55r9WyH1wV1whBRacLFa',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 170866,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6CVzXxIHDIDdyzlgfEWSZr'},
#    'href': 'https://api.spotify.com/v1/tracks/6CVzXxIHDIDdyzlgfEWSZr',
#    'id': '6CVzXxIHDIDdyzlgfEWSZr',
#    'name': "You're My Best Friend - Remastered 2011",
#    'preview_url': None,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6CVzXxIHDIDdyzlgfEWSZr',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 209653,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/064C5ivM2FUsY0ghkyt4YK'},
#    'href': 'https://api.spotify.com/v1/tracks/064C5ivM2FUsY0ghkyt4YK',
#    'id': '064C5ivM2FUsY0ghkyt4YK',
#    'name': "Don't Stop Me Now - Remastered 2011",
#    'preview_url': None,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:064C5ivM2FUsY0ghkyt4YK',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 228053,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5V890judRbpVT6X5AEYZc8'},
#    'href': 'https://api.spotify.com/v1/tracks/5V890judRbpVT6X5AEYZc8',
#    'id': '5V890judRbpVT6X5AEYZc8',
#    'name': 'Save Me - Remastered 2011',
#    'preview_url': None,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:5V890judRbpVT6X5AEYZc8',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 163360,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0q8IUBbw0iedjCbzs7vT6U'},
#    'href': 'https://api.spotify.com/v1/tracks/0q8IUBbw0iedjCbzs7vT6U',
#    'id': '0q8IUBbw0iedjCbzs7vT6U',
#    'name': 'Crazy Little Thing Called Love - Remastered 2011',
#    'preview_url': None,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:0q8IUBbw0iedjCbzs7vT6U',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 296453,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4RJdwSqHapVcW5DaRtTkv0'},
#    'href': 'https://api.spotify.com/v1/tracks/4RJdwSqHapVcW5DaRtTkv0',
#    'id': '4RJdwSqHapVcW5DaRtTkv0',
#    'name': 'Somebody To Love - Remastered 2011',
#    'preview_url': None,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:4RJdwSqHapVcW5DaRtTkv0',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 253373,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4NAgFUDP9yL0DascpS0bJb'},
#    'href': 'https://api.spotify.com/v1/tracks/4NAgFUDP9yL0DascpS0bJb',
#    'id': '4NAgFUDP9yL0DascpS0bJb',
#    'name': "Now I'm Here - Remastered 2011",
#    'preview_url': None,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:4NAgFUDP9yL0DascpS0bJb',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 173053,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5GQUVjaja81SDqQC6TuFdd'},
#    'href': 'https://api.spotify.com/v1/tracks/5GQUVjaja81SDqQC6TuFdd',
#    'id': '5GQUVjaja81SDqQC6TuFdd',
#    'name': 'Good Old-Fashioned Lover Boy - Remastered 2011',
#    'preview_url': None,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:5GQUVjaja81SDqQC6TuFdd',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 211840,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0p1c1SymyFwxiabvp0EjcV'},
#    'href': 'https://api.spotify.com/v1/tracks/0p1c1SymyFwxiabvp0EjcV',
#    'id': '0p1c1SymyFwxiabvp0EjcV',
#    'name': 'Play The Game - Remastered 2011',
#    'preview_url': None,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:0p1c1SymyFwxiabvp0EjcV',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 167373,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Xxra8s5kUaLy7CMRkw7mn'},
#    'href': 'https://api.spotify.com/v1/tracks/4Xxra8s5kUaLy7CMRkw7mn',
#    'id': '4Xxra8s5kUaLy7CMRkw7mn',
#    'name': 'Flash - Remastered 2011',
#    'preview_url': None,
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:4Xxra8s5kUaLy7CMRkw7mn',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 167026,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ZZYA2STqMdoMqtFHQCGJf'},
#    'href': 'https://api.spotify.com/v1/tracks/4ZZYA2STqMdoMqtFHQCGJf',
#    'id': '4ZZYA2STqMdoMqtFHQCGJf',
#    'name': 'Seven Seas Of Rhye - Remastered 2011',
#    'preview_url': None,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:4ZZYA2STqMdoMqtFHQCGJf',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 121813,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2wZtRh3I3JYPODpL4c07ZC'},
#    'href': 'https://api.spotify.com/v1/tracks/2wZtRh3I3JYPODpL4c07ZC',
#    'id': '2wZtRh3I3JYPODpL4c07ZC',
#    'name': 'We Will Rock You - Remastered 2011',
#    'preview_url': None,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:2wZtRh3I3JYPODpL4c07ZC',
#    'is_local': False},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#      'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#      'id': '1dfeR4HaWDbWqFHLkxsg1d',
#      'name': 'Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 186920,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5LRFuSfiF5xGbUfeHhWKAP'},
#    'href': 'https://api.spotify.com/v1/tracks/5LRFuSfiF5xGbUfeHhWKAP',
#    'id': '5LRFuSfiF5xGbUfeHhWKAP',
#    'name': 'We Are The Champions - Remastered 2011',
#    'preview_url': None,
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:5LRFuSfiF5xGbUfeHhWKAP',
#    'is_local': False}]}

# %%
track_num = 0
for track in queen_album['tracks']['items']:
    track_num += 1
    print(np.where(track_num <= 9, "Track  ", "Track "), str(track_num), " is ", track['name'])
# Out:
# Track   1  is  Bohemian Rhapsody - Remastered 2011
# Track   2  is  Another One Bites The Dust - Remastered 2011
# Track   3  is  Killer Queen - Remastered 2011
# Track   4  is  Fat Bottomed Girls - Single Version / Remastered 2011
# Track   5  is  Bicycle Race - Remastered 2011
# Track   6  is  You're My Best Friend - Remastered 2011
# Track   7  is  Don't Stop Me Now - Remastered 2011
# Track   8  is  Save Me - Remastered 2011
# Track   9  is  Crazy Little Thing Called Love - Remastered 2011
# Track  10  is  Somebody To Love - Remastered 2011
# Track  11  is  Now I'm Here - Remastered 2011
# Track  12  is  Good Old-Fashioned Lover Boy - Remastered 2011
# Track  13  is  Play The Game - Remastered 2011
# Track  14  is  Flash - Remastered 2011
# Track  15  is  Seven Seas Of Rhye - Remastered 2011
# Track  16  is  We Will Rock You - Remastered 2011
# Track  17  is  We Are The Champions - Remastered 2011

# %% [markdown]
# 7. Find an API of interest to you. Sign up for an API key if necessary. Describe the API concisely and make a single call on the API and return an example of the returned data here.

# %% [markdown]
# The **Yahoo Finance API** allows users to search for financial and company data published on Yahoo Finance. Potential searches include: company information, stock prices, corporate actions, and earnings history. The API also includes functions like `yfinance.Ticker()`, which allows users to access publicly-traded company data more easily through the company's stock ticker symbol.

# %%
# Company selected - BlackRock
blk = yf.Ticker("BLK")

# Get all stock info
blk.info
# Out:
# {'address1': '50 Hudson Yards',
#  'city': 'New York',
#  'state': 'NY',
#  'zip': '10001',
#  'country': 'United States',
#  'phone': '212 810 5300',
#  'website': 'https://www.blackrock.com',
#  'industry': 'Asset Management',
#  'industryKey': 'asset-management',
#  'industryDisp': 'Asset Management',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'BlackRock, Inc. is a privately owned investment manager. The firm primarily provides its services to institutional, intermediary, and individual investors including corporate, public, union, and industry pension plans, insurance companies, third-party mutual funds, endowments, public institutions, governments, foundations, charities, sovereign wealth funds, corporations, official institutions, and banks. It also provides global risk management and advisory services. The firm manages separate client-focused equity, fixed income, and balanced portfolios. It also launches and manages open-end and closed-end mutual funds, offshore funds, unit trusts, and alternative investment vehicles including structured funds. The firm launches equity, fixed income, balanced, and real estate mutual funds. It also launches equity, fixed income, balanced, currency, commodity, and multi-asset exchange traded funds. The firm also launches and manages hedge funds. It invests in the public equity, fixed income, real estate, currency, commodity, and alternative markets across the globe. The firm primarily invests in growth and value stocks of small-cap, mid-cap, SMID-cap, large-cap, and multi-cap companies. It also invests in dividend-paying equity securities. The firm invests in investment grade municipal securities, government securities including securities issued or guaranteed by a government or a government agency or instrumentality, corporate bonds, and asset-backed and mortgage-backed securities. It employs fundamental and quantitative analysis with a focus on bottom-up and top-down approach to make its investments. The firm employs liquidity, asset allocation, balanced, real estate, and alternative strategies to make its investments. In real estate sector, it seeks to invest in Poland and Germany. The firm benchmarks the performance of its portfolios against various S&P, Russell, Barclays, MSCI, Citigroup, and Merrill Lynch indices. BlackRock, Inc. was founded in 1988 and is based in New York, New York with additional offices in Atlanta, Georgia; Boston, Massachusetts; Chicago, Illinois; Dallas, Texas; Denver, Colorado; Greenwich, Connecticut; Houston, Texas; Miami, Florida; Newport Beach, California; Palo Alto, California; Philadelphia, Pennsylvania; Princeton, New Jersey; San Francisco, California; Santa Monica, California; Seattle, Washington; Washington, DC; West Palm Beach, Florida; Wilmington, Delaware; Mexico; Canada; South Africa; Netherlands; Greece; Serbia; Belgium; Hungary; Denmark; Ireland; Scotland; Germany; Switzerland; England; Luxembourg; Spain; Italy; France; Sweden; Austria; India; China; Australia; Hong Kong; South Korea; Singapore; Taiwan; Japan; Colombia; Argentina; Peru; Chile; Brazil; UAE; Saudi Arabia; Israel.',
#  'fullTimeEmployees': 23000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Laurence Douglas Fink',
#    'age': 72,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1952,
#    'fiscalYear': 2024,
#    'totalPay': 12618443,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert Steven Kapito',
#    'age': 68,
#    'title': 'President & Director',
#    'yearBorn': 1956,
#    'fiscalYear': 2024,
#    'totalPay': 8483737,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Martin S. Small',
#    'age': 48,
#    'title': 'Senior MD, CFO & Global Head of Corporate Strategy',
#    'yearBorn': 1976,
#    'fiscalYear': 2024,
#    'totalPay': 4154150,
#    'exercisedValue': 0,
#    'unexercisedValue': 13837516},
#   {'maxAge': 1,
#    'name': 'Mr. Robert Lawrence Goldstein',
#    'age': 50,
#    'title': 'Senior MD & COO',
#    'yearBorn': 1974,
#    'fiscalYear': 2024,
#    'totalPay': 4840270,
#    'exercisedValue': 28756620,
#    'unexercisedValue': 27724146},
#   {'maxAge': 1,
#    'name': 'Mr. J. Richard Kushel',
#    'age': 57,
#    'title': 'Senior MD & Head of the Portfolio Management Group',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 3993770,
#    'exercisedValue': 5255915,
#    'unexercisedValue': 34350520},
#   {'maxAge': 1,
#    'name': 'Dr. Bennett W. Golub Ph.D.',
#    'age': 66,
#    'title': 'Co-Founder',
#    'yearBorn': 1958,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mark  McKenna',
#    'title': 'Founder, MD, Global Head of Event Driven Equity Strategies & Portfolio Manager',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Jeff  Shen Ph.D.',
#    'title': 'MD, Co-CIO & Co-Head of Systematic Active Equity (SAE)',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Neeraj  Seth',
#    'title': 'MD, Chief Investment Officer & Head of Asian credit \x96 Singapore',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Pablo A. Goldberg',
#    'title': 'MD, Head of Research, Portfolio Manager & Senior Strategist',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 4,
#  'boardRisk': 7,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 9,
#  'governanceEpochDate': 1743465600,
#  'compensationAsOfEpochDate': 1735603200,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 889.95,
#  'open': 888.9,
#  'dayLow': 886.225,
#  'dayHigh': 900.52,
#  'regularMarketPreviousClose': 889.95,
#  'regularMarketOpen': 888.9,
#  'regularMarketDayLow': 886.225,
#  'regularMarketDayHigh': 900.52,
#  'dividendRate': 20.84,
#  'dividendYield': 2.34,
#  'exDividendDate': 1741305600,
#  'payoutRatio': 0.4982,
#  'fiveYearAvgDividendYield': 2.39,
#  'beta': 1.394,
#  'trailingPE': 21.68505,
#  'forwardPE': 18.196009,
#  'volume': 259410,
#  'regularMarketVolume': 259410,
#  'averageVolume': 969593,
#  'averageVolume10days': 1213310,
#  'averageDailyVolume10Day': 1213310,
#  'bid': 890.19,
#  'ask': 892.71,
#  'bidSize': 13,
#  'askSize': 14,
#  'marketCap': 138500374528,
#  'fiftyTwoWeekLow': 745.55,
#  'fiftyTwoWeekHigh': 1084.22,
#  'priceToSalesTrailing12Months': 6.609419,
#  'fiftyDayAverage': 946.744,
#  'twoHundredDayAverage': 947.46375,
#  'trailingAnnualDividendRate': 20.51,
#  'trailingAnnualDividendYield': 0.023046238,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 139430248448,
#  'profitMargins': 0.30093,
#  'floatShares': 152510700,
#  'sharesOutstanding': 155022000,
#  'sharesShort': 1466054,
#  'sharesShortPriorMonth': 1634784,
#  'sharesShortPreviousMonthDate': 1740700800,
#  'dateShortInterest': 1743379200,
#  'sharesPercentSharesOut': 0.0095,
#  'heldPercentInsiders': 0.02029,
#  'heldPercentInstitutions': 0.83569,
#  'shortRatio': 1.4,
#  'shortPercentOfFloat': 0.0095999995,
#  'impliedSharesOutstanding': 155022000,
#  'bookValue': 306.523,
#  'priceToBook': 2.9147046,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1743379200,
#  'earningsQuarterlyGrowth': -0.04,
#  'netIncomeToCommon': 6305999872,
#  'trailingEps': 41.2,
#  'forwardEps': 49.1,
#  'enterpriseToRevenue': 6.654,
#  'enterpriseToEbitda': 16.528,
#  '52WeekChange': 0.18712234,
#  'SandP52WeekChange': 0.07019031,
#  'lastDividendValue': 5.21,
#  'lastDividendDate': 1741305600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 893.424,
#  'targetHighPrice': 1111.0,
#  'targetLowPrice': 950.0,
#  'targetMeanPrice': 1033.9088,
#  'targetMedianPrice': 1035.0,
#  'recommendationMean': 1.66667,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 17,
#  'totalCash': 14593999872,
#  'totalCashPerShare': 94.155,
#  'ebitda': 8436250112,
#  'totalDebt': 14222000128,
#  'totalRevenue': 20955000832,
#  'debtToEquity': 28.816,
#  'revenuePerShare': 138.21,
#  'grossProfits': 10435000320,
#  'earningsGrowth': -0.08,
#  'revenueGrowth': 0.116,
#  'grossMargins': 0.49797,
#  'ebitdaMargins': 0.40258998,
#  'operatingMargins': 0.36353,
#  'financialCurrency': 'USD',
#  'symbol': 'BLK',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'longName': 'BlackRock, Inc.',
#  'corporateActions': [],
#  'regularMarketTime': 1744742283,
#  'exchange': 'NYQ',
#  'messageBoardId': 'finmb_403413',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'REGULAR',
#  'regularMarketChangePercent': 0.3903589,
#  'regularMarketPrice': 893.424,
#  'priceEpsCurrentYear': 19.905058,
#  'fiftyDayAverageChange': -53.320007,
#  'fiftyDayAverageChangePercent': -0.05631935,
#  'twoHundredDayAverageChange': -54.039734,
#  'twoHundredDayAverageChangePercent': -0.057036202,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.7 - Buy',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 938784600000,
#  'regularMarketChange': 3.473999,
#  'regularMarketDayRange': '886.225 - 900.52',
#  'fullExchangeName': 'NYSE',
#  'averageDailyVolume3Month': 969593,
#  'fiftyTwoWeekLowChange': 147.87402,
#  'fiftyTwoWeekLowChangePercent': 0.1983422,
#  'fiftyTwoWeekRange': '745.55 - 1084.22',
#  'fiftyTwoWeekHighChange': -190.79596,
#  'fiftyTwoWeekHighChangePercent': -0.17597532,
#  'fiftyTwoWeekChangePercent': 18.712234,
#  'dividendDate': 1742774400,
#  'earningsTimestamp': 1744365600,
#  'earningsTimestampStart': 1752496200,
#  'earningsTimestampEnd': 1753792200,
#  'earningsCallTimestampStart': 1744371000,
#  'earningsCallTimestampEnd': 1744371000,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 41.2,
#  'epsForward': 49.1,
#  'epsCurrentYear': 44.88427,
#  'shortName': 'BlackRock, Inc.',
#  'displayName': 'BlackRock',
#  'trailingPegRatio': 1.5804}

# %%
# Get historical stock data
hist = blk.history(period="1mo")
hist.head(10)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-03-17 00:00:00-04:00  937.130005  960.940002  933.369995  958.000000
# 2025-03-18 00:00:00-04:00  957.630005  964.570007  956.010010  958.619995
# 2025-03-19 00:00:00-04:00  959.679993  966.000000  951.000000  957.229980
# 2025-03-20 00:00:00-04:00  952.690002  961.630005  949.520020  954.169983
# 2025-03-21 00:00:00-04:00  948.000000  956.340027  938.169983  951.729980
# 2025-03-24 00:00:00-04:00  960.650024  972.989990  957.000000  963.500000
# 2025-03-25 00:00:00-04:00  970.479980  977.280029  961.859985  973.479980
# 2025-03-26 00:00:00-04:00  975.000000  980.200012  964.000000  968.239990
# 2025-03-27 00:00:00-04:00  965.510010  976.799988  957.500000  967.940002
# 2025-03-28 00:00:00-04:00  966.239990  967.650024  945.770020  946.700012
#
#                             Volume  Dividends  Stock Splits
# Date
# 2025-03-17 00:00:00-04:00   922300        0.0           0.0
# 2025-03-18 00:00:00-04:00  1086200        0.0           0.0
# 2025-03-19 00:00:00-04:00  1086700        0.0           0.0
# 2025-03-20 00:00:00-04:00   667900        0.0           0.0
# 2025-03-21 00:00:00-04:00  5211600        0.0           0.0
# 2025-03-24 00:00:00-04:00   640000        0.0           0.0
# 2025-03-25 00:00:00-04:00   566700        0.0           0.0
# 2025-03-26 00:00:00-04:00   667600        0.0           0.0
# 2025-03-27 00:00:00-04:00   479100        0.0           0.0
# 2025-03-28 00:00:00-04:00   568800        0.0           0.0

# %% [markdown]
# Q.1-10
#
# Q.2-10
#
# Q.3-10
#
# Q.4-10
#
# Q.5-10
#
# Q.6-25
#
# Q.7-25

# %% [markdown]
# 8. Import the data found in the HW5 folder. It is a single column of data that has 500 rows. This data represents a format of data that you will often encounter in reserach projects which use "thematic coding" for text response data. As described [here](https://www.betterevaluation.org/methods-approaches/methods/thematic-coding): "Thematic coding is a form of qualitative analysis that involves recording or identifying passages of text or images that are linked by a common theme or idea allowing you to index the text into categories and therefore establish a 'framework of thematic ideas about it' (Gibbs 2007)."
#
# It is ok if you are not familiar with thematic coding for qualitative/text data. Your task is to import the data and write a regex that is capable of finding the thematic code "1" whenever it appears in the string. This is more difficult than it sounds, because your regex should count all the "1"s that appear, but not "10", "11", "12", "21" etc. Also note, that sometimes "1" appears in the 2nd, 3rd… etc. position (e.g., "2, 6, 7, 1, 10"). Use this regex to add a new column to your dataset called "find_1". Display a frequency table showing the number of times your regex flagged "1" as appearing.

# %%
file = r"C:\Users\nicho\OneDrive\Desktop\MDS\QMSS-GR5072-Spring2025-HWs\homework-5-main\data\Thematic codes data.csv"
df = pd.read_csv(file)
df
# Out:
#       Thematic codes
# 0              1, 16
# 1                  1
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 495               24
# 496            8, 24
# 497  2, 8, 9, 16, 21
# 498             4, 8
# 499            8, 25
#
# [500 rows x 1 columns]

# %%
import re 
df["find_1"] = df['Thematic codes'].str.contains("\\b1\\b")
df.find_1.value_counts()
# Out:
# find_1
# False    437
# True      63
# Name: count, dtype: int64

# %%
# Check your work !
df.to_csv(r"C:\Users\nicho\OneDrive\Desktop\MDS\QMSS-GR5072-Spring2025-HWs\homework-5-main\data\check.csv")

# %%
# You can also ask chat GPT ! It gave me this crazier answer, but it worked 
df["find_2"] = df['Thematic codes'].str.contains("(?<!\d)(1(?![0-9])|(?<!\d),1(?!$))(?!\d)")
df.find_2.value_counts()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\nicho\AppData\Local\Temp\ipykernel_1332\2896106094.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df["find_2"] = df['Thematic codes'].str.contains("(?<!\d)(1(?![0-9])|(?<!\d),1(?!$))(?!\d)")
# C:\Users\nicho\AppData\Local\Temp\ipykernel_1332\2896106094.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df["find_2"] = df['Thematic codes'].str.contains("(?<!\d)(1(?![0-9])|(?<!\d),1(?!$))(?!\d)")
# find_2
# False    437
# True      63
# Name: count, dtype: int64
